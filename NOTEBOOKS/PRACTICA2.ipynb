# %%
import pandas as pd

# %%
# Cargar datos
df = pd.read_csv(r"C:\Users\angel\OneDrive\Escritorio\OCTAVO SEM\MINERIA DE DATOS\REPOSITORIO\AOAG_MinDat035\DATASET\players_20.csv")

# %%
# Visualizar los primeros registros
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, CF, ST
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 3          E. Hazard                          Eden Hazard           LW, CF
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
# Estadísticas generales (media, mediana, etc.)
df.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   18483.000000  18483.000000  18483.000000  1.823300e+04   18243.000000
# mean   219768.374885     66.198885     71.500893  2.495171e+06    9745.598312
# std     28047.535516      6.950927      6.140787  5.587820e+06   21448.995068
# min        41.000000     48.000000     49.000000  8.000000e+03     500.000000
# 25%    204495.500000     62.000000     67.000000  3.250000e+05    1000.000000
# 50%    226215.000000     66.000000     71.000000  7.250000e+05    3000.000000
# 75%    240880.000000     71.000000     75.000000  2.100000e+06    9000.000000
# max    252905.000000     94.000000     95.000000  1.055000e+08  560000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  18483.000000  18483.000000  18483.000000   18243.000000  17858.000000
# mean      25.283071    181.348212     75.259049   45222.312723      1.400997
# ...

# %%
# Conteo de jugadores por nacionalidad
df['nationality_name'].value_counts().head(10)
# Out:
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
# Brazil          827
# Italy           732
# Colombia        612
# Japan           479
# Netherlands     416
# Name: nationality_name, dtype: int64

# %%
# Media de overall por club (primeros 10)
df.groupby('club_name')['overall'].mean().sort_values(ascending=False).head(10)
# Out:
# club_name
# FC Bayern München      81.304348
# Real Madrid CF         80.121212
# Juventus               80.060606
# FC Barcelona           78.363636
# Bayer 04 Leverkusen    77.280000
# Chelsea                77.060606
# Manchester City        77.000000
# Napoli                 76.870968
# Manchester United      76.848485
# Tottenham Hotspur      76.484848
# Name: overall, dtype: float64

# %%
# Comparación por pierna preferida
df.groupby('preferred_foot')['overall'].mean()
# Out:
# preferred_foot
# Left     66.647072
# Right    66.060730
# Name: overall, dtype: float64

# %%
# Agrupación por ST, CM, CB, GK
df[df['player_positions'].str.split(',').str[0].isin(['ST', 'CM', 'CB', 'GK'])] \
  .groupby(df['player_positions'].str.split(',').str[0])['overall'] \
  .mean().sort_values(ascending=False)
# Out:
# player_positions
# CB    66.628402
# ST    66.378109
# CM    65.711252
# GK    64.734110
# Name: overall, dtype: float64
